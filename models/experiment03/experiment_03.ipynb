# %% [markdown]
# # Experiment 02
#
# According to experiment 01: try remove 'right' dataset to debug the problem
#
# 1. load all dataset ['lanefollow', 'straight', 'right']
#     - Train/Test: 60/40
# 2. model build according to the paper
#     1. image module: activation elu
#     2. the rest module: activation relu
#     3. final layer: activation sigmoid
#
# 3. hyperparameter
#     1. nb_epoch = 20
#     2. samples_per_epoch = 35000
#     3. batch_size = 42
#     4. learning_rate 1.0e-4
#
# ### What does it change?
# - from: load all dataset ['lanefollow', 'straight', 'left']
# - to: load all dataset ['lanefollow', 'straight', 'right']
#
# - from: batch_size = 40
# - to: batch_size = 42

# %%
# %reload_ext autoreload

# %%
# %autoreload 2

# %%
import pandas as pd # data analysis toolkit - create, read, update, delete datasets
import numpy as np # matrix math
from sklearn.model_selection import train_test_split #to split out training and testing data 
#keras is a high level wrapper on top of tensorflow (machine learning library)
#The Sequential container is a linear stack of layers
from keras.models import Sequential, Model
#popular optimization strategy that uses gradient descent 
from keras.optimizers import Adam
#to save our model periodically as checkpoints for loading later
from keras.callbacks import ModelCheckpoint, EarlyStopping
#what types of layers do we want our model to have?
from keras.layers import Lambda, Conv2D, MaxPooling2D, Dropout, GlobalAveragePooling1D, Dense, Flatten, LSTM, Activation, ZeroPadding2D, TimeDistributed, Input, concatenate
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
#for command line arguments
import argparse
#for reading files
import os
#for ploting graph
import matplotlib.pyplot as plt
import timeit
import math
# Out:
# /home/ploymel/anaconda3/envs/py35/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import nbimporter # pip install nbimporter
import utils as utils
import importlib
importlib.reload(utils)
# Out:
# Importing Jupyter notebook from utils.ipynb
# Importing Jupyter notebook from utils.ipynb
# <module 'utils' from 'utils.ipynb'>

# %%
IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS = 66, 200, 3
INPUT_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)

# %%
def load_data(folder_name, test_size_value=0.4):
    """
    Load training data and split it into training and validation set
    """
    #reads CSV file into a single dataframe variable
    data_df = pd.read_csv(os.path.join('../..', '_out', folder_name, 'train_3/data.csv'))

    #yay dataframes, we can select rows and columns by their names
    #we'll store the camera images as our input data
    X = data_df[['image_path', 'speed', 'high_level_command']].values
    #and our steering commandas as our output data
    Y = data_df[['throttle', 'steering_angle', 'brake']].values
    
    X_lanefollow = []
    X_straight = []
    X_right = []
    
    Y_lanefollow = []
    Y_straight = []
    Y_right = []
    
    X_image_path = X[:, 0]
    index = 0
    for path in X_image_path:
        path = path.split('/')
        if path[3] == 'lanefollow':
            X_lanefollow.append(X[index])
            Y_lanefollow.append(Y[index])
        elif path[3] == 'straight':
            X_straight.append(X[index])
            Y_straight.append(Y[index])
        elif path[3] == 'right':
            X_right.append(X[index])
            Y_right.append(Y[index])
        index += 1
        
    X_lanefollow = np.array(X_lanefollow)
    X_straight = np.array(X_straight)
    X_right = np.array(X_right)
    
    Y_lanefollow = np.array(Y_lanefollow)
    Y_straight = np.array(Y_straight)
    Y_right = np.array(Y_right)
    # we're going to use all training data so, we will use only len(X_train) * 40 / 60 of validating data
    # so, our ratio is going to be 60% for training set and 40% for validation set and for testing
    # we're going to test in the simulation environment which is town01
    X_train_lanefollow, X_valid_lanefollow, Y_train_lanefollow, Y_valid_lanefollow = train_test_split(X_lanefollow, Y_lanefollow, test_size=0.4, random_state=2)
    X_train_straight, X_valid_straight, Y_train_straight, Y_valid_straight         = train_test_split(X_straight, Y_straight, test_size=0.4, random_state=1)
    X_train_right, X_valid_right, Y_train_right, Y_valid_right                     = train_test_split(X_right, Y_right, test_size=0.4, random_state=1)
    
    X_train = [X_train_lanefollow, X_train_straight, X_train_right]
    Y_train = [Y_train_lanefollow, Y_train_straight, Y_train_right]
    
    X_valid = [X_valid_lanefollow, X_valid_straight, X_valid_right]
    Y_valid = [Y_valid_lanefollow, Y_valid_straight, Y_valid_right]
    
    print('X_train shape = (%d, %d)'% ((X_train[0].shape[0] + X_train[1].shape[0] + X_train[2].shape[0]), 3))
    print('Y_train shape = (%d, %d)'% ((Y_train[0].shape[0] + Y_train[1].shape[0] + Y_train[2].shape[0]), 3))
    print('X_valid shape = (%d, %d)'% ((X_valid[0].shape[0] + X_valid[1].shape[0] + X_valid[2].shape[0]), 3))
    print('Y_valid shape = (%d, %d)'% ((Y_valid[0].shape[0] + Y_valid[1].shape[0] + Y_valid[2].shape[0]), 3))

    return X_train, X_valid, Y_train, Y_valid

# %%
def build_model(args):
    
    input_image = Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS), name='input_image')
    input_speed = Input(shape=(1, ), name='input_speed')
    input_command = Input(shape=(1, ), name='input_command')
    
    """conv 1"""
    xc = Conv2D(32, kernel_size=(5, 5), strides=(2, 2), padding="valid", name='conv_1_1')(input_image)
    xc = BatchNormalization()(xc)
    xc = Activation('elu')(xc)
    
    xc = Conv2D(32, kernel_size=(3, 3), strides=(1, 1), padding="valid", name='conv_1_2')(xc)
    xc = BatchNormalization()(xc)
    xc = Activation('elu')(xc)
    
    """conv 2"""
    xc = Conv2D(64, kernel_size=(3,3), strides=(2, 2), padding="valid", name="conv_2_1")(xc)
    xc = BatchNormalization()(xc)
    xc = Activation('elu')(xc)
    
    xc = Conv2D(64, kernel_size=(3,3), strides=(1, 1), padding="valid", name="conv_2_2")(xc)
    xc = BatchNormalization()(xc)
    xc = Activation('elu')(xc)
    
    """conv 3"""
    xc = Conv2D(128, kernel_size=(3,3), strides=(2, 2), padding="valid", name="conv_3_1")(xc)
    xc = BatchNormalization()(xc)
    xc = Activation('elu')(xc)
    
    xc = Conv2D(128, kernel_size=(3,3), strides=(1, 1), padding="valid", name="conv_3_2")(xc)
    xc = BatchNormalization()(xc)
    xc = Activation('elu')(xc)
    
    """conv 4"""
    xc = Conv2D(256, kernel_size=(3,3), strides=(1, 1), padding="valid", name="conv_4_1")(xc)
    xc = BatchNormalization()(xc)
    xc = Activation('elu')(xc)

    xc = Conv2D(256, kernel_size=(1,1), strides=(1, 1), padding="valid", name="conv_4_2")(xc)
    xc = BatchNormalization()(xc)
    xc = Activation('elu')(xc)

    """Flatten"""
    x = Flatten()(xc)
    
    """fc 1"""
    x = Dense(512, name="fc_1")(x)
    x = Activation('elu')(x)
    x = Dropout(0.5)(x)
    
    """fc 2"""
    x = Dense(512, name="fc_2")(x)
    x = Activation('elu')(x)
    x = Dropout(0.5)(x)
    
    """Process Control"""
    
    """Speed (measurements)"""
    speed = Dense(128, name="speed_fc_1")(input_speed)
    speed = Activation('relu')(speed)
    speed = Dropout(0.5)(speed)
    
    speed = Dense(128, name="speed_fc_2")(speed)
    speed = Activation('relu')(speed)
    spped = Dropout(0.5)(speed)
    
    """High Level Command"""
    cmd = Dense(128, name="cmd_fc_1")(input_command)
    cmd = Activation('relu')(cmd)
    cmd = Dropout(0.5)(cmd)
    
    cmd = Dense(128, name="cmd_fc_2")(cmd)
    cmd = Activation('relu')(cmd)
    cmd = Dropout(0.5)(cmd)

    # concatenate x, speed and cmd (joint sensory)
    j = concatenate([x, speed, cmd])
    j = Dense(512, name="joint_fc")(j)
    j = Activation('relu')(j)
    j = Dropout(0.5)(j)
    
    """Action"""
    output = Dense(512, name="action_fc_1")(j)
    output = Activation('relu')(output)
    output = Dropout(0.5)(output) 
    
    output = Dense(256, name="action_fc_2")(output)
    output = Activation('relu')(output)
    output = Dropout(0.5)(output) 
    
    output = Dense(256, name="action_fc_3")(output)
    output = Activation('relu')(output)
    output = Dropout(0.5)(output) 
    
    output = Dense(3, name="action_fc_4", activation='sigmoid')(output)
        
    model = Model(inputs=[input_image, input_speed, input_command], outputs=output)
    model.summary()

    return model

# %%
def train_model(model, args, X_train, X_test, Y_train, Y_test):
    """
    Train the model
    """
    #Saves the model after every epoch.
    #quantity to monitor, verbosity i.e logging mode (0 or 1), 
    #if save_best_only is true the latest best model according to the quantity monitored will not be overwritten.
    #mode: one of {auto, min, max}. If save_best_only=True, the decision to overwrite the current save file is
    # made based on either the maximization or the minimization of the monitored quantity. For val_acc, 
    #this should be max, for val_loss this should be min, etc. In auto mode, the direction is automatically
    # inferred from the name of the monitored quantity.
    callbacks = [EarlyStopping(monitor='val_loss', patience=2),
                 ModelCheckpoint('model-{epoch:03d}.h5',
                                 monitor='val_loss',
                                 verbose=0,
                                 save_best_only=args['save_best_only'],
                                 mode='auto')]
    #calculate the difference between expected steering angle and actual steering angle
    #square the difference
    #add up all those differences for as many data points as we have
    #divide by the number of them
    #that value is our mean squared error! this is what we want to minimize via
    #gradient descent
    model.compile(loss='mean_squared_error', optimizer=Adam(lr=args['learning_rate']), metrics=['accuracy'])

    #Fits the model on data generated batch-by-batch by a Python generator.

    #The generator is run in parallel to the model, for efficiency. 
    #For instance, this allows you to do real-time data augmentation on images on CPU in 
    #parallel to training your model on GPU.
    #so we reshape our data into their appropriate batches and train our model simulatenously
    history = model.fit_generator(utils.batch_generator(X_train, Y_train, args['batch_size'], True),
                        args['samples_per_epoch'],
                        args['nb_epoch'],
                        max_q_size=1,
                        validation_data=utils.batch_generator(X_valid, Y_valid, args['batch_size'], False),
                        nb_val_samples=X_valid[0].shape[0],
                        callbacks=callbacks,
                        verbose=1)

    return history

# %%
def plot_loss_accuracy(history):
    fig = plt.figure(figsize=(12, 6))
    ax = fig.add_subplot(1, 2, 1)
    ax.plot(history.history["loss"],'r-x', label="Train Loss")
    ax.plot(history.history["val_loss"],'b-x', label="Validation Loss")
    ax.legend()
    ax.set_title('loss')
    ax.grid(True)


    ax = fig.add_subplot(1, 2, 2)
    ax.plot(history.history["acc"],'r-x', label="Train Accuracy")
    ax.plot(history.history["val_acc"],'b-x', label="Validation Accuracy")
    ax.legend()
    ax.set_title('accuracy')
    ax.grid(True)

# %%
args = {
        'nb_epoch': 20,
        'samples_per_epoch': 35000,
        'batch_size': 42,
        'save_best_only': True,
        'learning_rate': 1.0e-4
}

# build model
model = build_model(args)
X_train, X_valid, Y_train, Y_valid = load_data('no_obstacle_no_traffic')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        (None, 66, 200, 3)   0
# __________________________________________________________________________________________________
# conv_1_1 (Conv2D)               (None, 31, 98, 32)   2432        input_image[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 31, 98, 32)   128         conv_1_1[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 31, 98, 32)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv_1_2 (Conv2D)               (None, 29, 96, 32)   9248        activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 29, 96, 32)   128         conv_1_2[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 29, 96, 32)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv_2_1 (Conv2D)               (None, 14, 47, 64)   18496       activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 14, 47, 64)   256         conv_2_1[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 14, 47, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv_2_2 (Conv2D)               (None, 12, 45, 64)   36928       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 12, 45, 64)   256         conv_2_2[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 12, 45, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv_3_1 (Conv2D)               (None, 5, 22, 128)   73856       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 5, 22, 128)   512         conv_3_1[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 5, 22, 128)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv_3_2 (Conv2D)               (None, 3, 20, 128)   147584      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 3, 20, 128)   512         conv_3_2[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 3, 20, 128)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv_4_1 (Conv2D)               (None, 1, 18, 256)   295168      activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 1, 18, 256)   1024        conv_4_1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 1, 18, 256)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv_4_2 (Conv2D)               (None, 1, 18, 256)   65792       activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 1, 18, 256)   1024        conv_4_2[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 1, 18, 256)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 4608)         0           activation_26[0][0]
# __________________________________________________________________________________________________
# input_command (InputLayer)      (None, 1)            0
# __________________________________________________________________________________________________
# fc_1 (Dense)                    (None, 512)          2359808     flatten_2[0][0]
# __________________________________________________________________________________________________
# input_speed (InputLayer)        (None, 1)            0
# __________________________________________________________________________________________________
# cmd_fc_1 (Dense)                (None, 128)          256         input_command[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 512)          0           fc_1[0][0]
# __________________________________________________________________________________________________
# speed_fc_1 (Dense)              (None, 128)          256         input_speed[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 128)          0           cmd_fc_1[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 512)          0           activation_27[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 128)          0           speed_fc_1[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 128)          0           activation_31[0][0]
# __________________________________________________________________________________________________
# fc_2 (Dense)                    (None, 512)          262656      dropout_11[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 128)          0           activation_29[0][0]
# __________________________________________________________________________________________________
# cmd_fc_2 (Dense)                (None, 128)          16512       dropout_15[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 512)          0           fc_2[0][0]
# __________________________________________________________________________________________________
# speed_fc_2 (Dense)              (None, 128)          16512       dropout_13[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 128)          0           cmd_fc_2[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 512)          0           activation_28[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 128)          0           speed_fc_2[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 128)          0           activation_32[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 768)          0           dropout_12[0][0]
#                                                                  activation_30[0][0]
#                                                                  dropout_16[0][0]
# __________________________________________________________________________________________________
# joint_fc (Dense)                (None, 512)          393728      concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 512)          0           joint_fc[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 512)          0           activation_33[0][0]
# __________________________________________________________________________________________________
# action_fc_1 (Dense)             (None, 512)          262656      dropout_17[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 512)          0           action_fc_1[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 512)          0           activation_34[0][0]
# __________________________________________________________________________________________________
# action_fc_2 (Dense)             (None, 256)          131328      dropout_18[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 256)          0           action_fc_2[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 256)          0           activation_35[0][0]
# __________________________________________________________________________________________________
# action_fc_3 (Dense)             (None, 256)          65792       dropout_19[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 256)          0           action_fc_3[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 256)          0           activation_36[0][0]
# __________________________________________________________________________________________________
# action_fc_4 (Dense)             (None, 3)            771         dropout_20[0][0]
# ==================================================================================================
# Total params: 4,163,619
# Trainable params: 4,161,699
# Non-trainable params: 1,920
# __________________________________________________________________________________________________
# X_train shape = (27143, 3)
# Y_train shape = (27143, 3)
# X_valid shape = (18097, 3)
# Y_valid shape = (18097, 3)

# %%
utils.show_image(utils.load_image(X_train[2][1][0]))

# %%
utils.show_image(utils.preprocess(utils.load_image(X_train[2][84][0])))

# %% [markdown]
# # Load train/validation data set and train the model

# %%
#print parameters
print('-' * 30)
print('Parameters')
print('-' * 30)
for key in args:
    print('{:<20} := {}'.format(key, args[key]))
print('-' * 30)

# train model on validation data, it saves as model.h5 
# Comment out when you finish validation and about to start the real training with test dataset
start = timeit.default_timer()
history = train_model(model, args, X_train, X_valid, Y_train, Y_valid)
stop = timeit.default_timer()
elasped = stop - start
hour = math.floor(elasped / 3600)
minute = math.floor((elasped - hour * 3600) / 60)
second = elasped - ((hour * 3600) + (minute * 60))
print('-' * 30)
print('Time use: %d hours %d minutes %d seconds.' % (hour, minute, second)) 
print('-' * 30)

# visualize training and validation
plot_loss_accuracy(history)
# Out:
# ------------------------------
# Parameters
# ------------------------------
# learning_rate        := 0.0001
# batch_size           := 42
# samples_per_epoch    := 35000
# nb_epoch             := 20
# save_best_only       := True
# ------------------------------
# /home/ploymel/anaconda3/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:39: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /home/ploymel/anaconda3/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:39: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., 35000, 20, validation_data=<generator..., verbose=1, validation_steps=8001, max_queue_size=1, callbacks=[<keras.ca...)`
# Epoch 1/20
# 35000/35000 [==============================] - 4331s 124ms/step - loss: 0.0024 - acc: 0.6872 - val_loss: 0.0021 - val_acc: 0.7162
# Epoch 2/20
# 35000/35000 [==============================] - 4295s 123ms/step - loss: 5.9293e-04 - acc: 0.7083 - val_loss: 8.1895e-04 - val_acc: 0.7047
# Epoch 3/20
# 35000/35000 [==============================] - 4309s 123ms/step - loss: 3.1585e-04 - acc: 0.7546 - val_loss: 7.5132e-04 - val_acc: 0.7828
# Epoch 4/20
# 35000/35000 [==============================] - 4283s 122ms/step - loss: 2.5333e-04 - acc: 0.7757 - val_loss: 7.5287e-04 - val_acc: 0.7902
# Epoch 5/20
# 35000/35000 [==============================] - 4292s 123ms/step - loss: 2.1916e-04 - acc: 0.7792 - val_loss: 7.3397e-04 - val_acc: 0.7869
# Epoch 6/20
# 35000/35000 [==============================] - 4321s 123ms/step - loss: 1.9637e-04 - acc: 0.7766 - val_loss: 7.2260e-04 - val_acc: 0.7863
# Epoch 7/20
# 35000/35000 [==============================] - 4347s 124ms/step - loss: 1.8353e-04 - acc: 0.7780 - val_loss: 7.8854e-04 - val_acc: 0.7843
# Epoch 8/20
# 35000/35000 [==============================] - 4299s 123ms/step - loss: 1.7119e-04 - acc: 0.7793 - val_loss: 6.9395e-04 - val_acc: 0.7850
# Epoch 9/20
# 35000/35000 [==============================] - 4443s 127ms/step - loss: 1.6315e-04 - acc: 0.7813 - val_loss: 6.7758e-04 - val_acc: 0.7880
# Epoch 10/20
# 35000/35000 [==============================] - 4358s 125ms/step - loss: 1.5697e-04 - acc: 0.7847 - val_loss: 6.9611e-04 - val_acc: 0.7903
# Epoch 11/20
# 35000/35000 [==============================] - 4251s 121ms/step - loss: 1.4785e-04 - acc: 0.7864 - val_loss: 6.8243e-04 - val_acc: 0.7924
# ------------------------------
# Time use: 13 hours 12 minutes 12 seconds.
# ------------------------------
